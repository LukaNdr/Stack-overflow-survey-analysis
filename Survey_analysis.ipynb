# %%
import pandas as pd 
#import data
df = pd.read_csv('data/survey_results_public.csv')

#print data first 5 rows
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
#print data shape
df.shape
# Out:
# (89184, 84)

# %%
#data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           89184 non-null  int64
#  1   Q120                                 89184 non-null  object
#  2   MainBranch                           89184 non-null  object
#  3   Age                                  89184 non-null  object
#  4   Employment                           87898 non-null  object
#  5   RemoteWork                           73810 non-null  object
#  6   CodingActivities                     73764 non-null  object
#  7   EdLevel                              87973 non-null  object
#  8   LearnCode                            87663 non-null  object
#  9   LearnCodeOnline                      70084 non-null  object
#  10  LearnCodeCoursesCert                 37076 non-null  object
# ...

# %%
#last 5 rows
df.tail()
# Out:
#        ResponseId     Q120                      MainBranch  \
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 89179     25-34 years old  Employed, full-time;Independent contractor, fr...
# 89180     18-24 years old             Student, full-time;Employed, part-time
# 89181   Prefer not to say                                I prefer not to say
# 89182  Under 18 years old             Employed, part-time;Student, part-time
# 89183     35-44 years old                                Employed, full-time
#
#                                  RemoteWork  \
# 89179                                Remote
# 89180  Hybrid (some remote, some in-person)
# ...

# %%
# set how many columns and rows do we need
pd.set_option('display.max_columns', 84)
pd.set_option('display.max_rows', 20)

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
schema_df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2   QID310         Q310  <div><span style="font-size:19px;"><strong>You...
# 3   QID312         Q120
# 4     QID1           S1  <span style="font-size:22px; font-family: aria...
# ..     ...          ...                                                ...
# 73  QID289  Knowledge_7  Waiting on answers to questions often causes i...
# 74  QID289  Knowledge_8  I feel like I have the tools and/or resources ...
# 75  QID290  Frequency_1  Needing help from people outside of your immed...
# 76  QID290  Frequency_2  Interacting with people outside of your immedi...
# 77  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# ...

# %%
# with the index_col function we print data which starting from ResponseID and second from qname
df = pd.read_csv('data/survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='qname')

# %%
df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# ...

# %%
schema_df
# Out:
#                 qid                                           question  \
# qname
# S0            QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo      QID12                                  Browser Meta Info
# Q310         QID310  <div><span style="font-size:19px;"><strong>You...
# Q120         QID312
# S1             QID1  <span style="font-size:22px; font-family: aria...
# ...             ...                                                ...
# Knowledge_7  QID289  Waiting on answers to questions often causes i...
# Knowledge_8  QID289  I feel like I have the tools and/or resources ...
# Frequency_1  QID290  Needing help from people outside of your immed...
# Frequency_2  QID290  Interacting with people outside of your immedi...
# Frequency_3  QID290  Encountering knowledge silos (where one indivi...
#
#             force_resp  type selector
# qname
# S0               False    DB       TB
# MetaInfo         False  Meta  Browser
# ...

# %%
#sorting data
schema_df.sort_index(inplace=True)

# %%
schema_df
# Out:
#                  qid                                           question  \
# qname
# AIAcc         QID324  For the AI tools you use as part of your devel...
# AIBen         QID316  How much do you trust the accuracy of the outp...
# AIDev         QID328  Which <b>AI-powered developer tools</b> did yo...
# AINext        QID320  Thinking about how your workflow and process c...
# AIOpen        QID321  Please describe how you would expect your work...
# ...              ...                                                ...
# ToolsTech     QID275  Which <b>developer </b><strong>tools for compi...
# Webframe      QID264  Which <b>web frameworks and web technologies</...
# WorkExp       QID288  How many years of working experience do you have?
# YearsCode      QID32  Including any education, how many years have y...
# YearsCodePro   QID34  NOT including education, how many years have y...
#
#              force_resp    type selector
# qname
# AIAcc             False      MC     MAVR
# ...

# %%
#counting how many elemnets we have
df['RemoteWork'].value_counts()
# Out:
# RemoteWork
# Hybrid (some remote, some in-person)    31131
# Remote                                  30566
# In-person                               12113
# Name: count, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Name: count, Length: 185, dtype: int64

# %%
df['Currency'].value_counts()
# Out:
# Currency
# EUR European Euro            17651
# USD\tUnited States dollar    16729
# GBP\tPound sterling           4473
# INR\tIndian rupee             3615
# CAD\tCanadian dollar          2647
#                              ...
# SDG\tSudanese pound              1
# JEP\tJersey pound                1
# KMF\tComorian franc              1
# CVE\tCape Verdean escudo         1
# SSP\tSouth Sudanese pound        1
# Name: count, Length: 144, dtype: int64

# %%
#filtring with languages
languages = ['Python', 'JavaScript', 'Kotlin']
lan_filt = df['LanguageHaveWorkedWith'].isin(languages)
lan_filt
# Out:
# ResponseId
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
#          ...
# 89163    False
# 89167    False
# 89168    False
# 89171    False
# 89172    False
# Name: LanguageHaveWorkedWith, Length: 48019, dtype: bool

# %%
# Select rows from the DataFrame 'df' based on a filter condition 'lan_filt' and extract the 'LanguageHaveWorkedWith' column.
lan_loc = df.loc[lan_filt, 'LanguageHaveWorkedWith']
lan_loc
# Out:
# ResponseId
# 43       JavaScript
# 331      JavaScript
# 353          Python
# 479          Python
# 663          Python
#             ...
# 88604        Python
# 88768        Python
# 88799    JavaScript
# 88885    JavaScript
# 89146        Python
# Name: LanguageHaveWorkedWith, Length: 742, dtype: object

# %%
lan_loc.count()
# Out:
# 742

# %%
currency = ['EUR European Euro', 'USD\tUnited States dollar', 'GBP\tPound sterling']
curr_filt = df['Currency'].isin(currency)
curr_filt.head()
# Out:
# ResponseId
# 1    False
# 2     True
# 3     True
# 4     True
# 5    False
# Name: Currency, dtype: bool

# %%
curr_loc = df.loc[curr_filt, 'Currency']
# Out:
# dtype('O')

# %%
countries = ['Georgia','United States of America', 'Germany', 'India', 'Canada']
country_filt = df['Country'].isin(countries)
country_filt.head(20)
# Out:
# ResponseId
# 1     False
# 2      True
# 3      True
# 4      True
# 5     False
# 6     False
# 7      True
# 8      True
# 9     False
# 10     True
# 11     True
# 12    False
# 13     True
# 14     True
# 15    False
# 16     True
# 17    False
# 18    False
# 19    False
# 20     True
# Name: Country, dtype: bool

# %%
df.loc[country_filt, 'Country'].head(20)
# Out:
# ResponseId
# 2     United States of America
# 3     United States of America
# 4     United States of America
# 7     United States of America
# 8     United States of America
# 10                       India
# 11    United States of America
# 13    United States of America
# 14    United States of America
# 16                     Germany
# 20                     Germany
# 22                     Germany
# 24                     Germany
# 33                     Germany
# 37    United States of America
# 38                     Germany
# 41                      Canada
# 42                     Germany
# 43    United States of America
# 44    United States of America
# Name: Country, dtype: object

# %%
#combining 3 filters and make one filter
combined_filt = lan_filt & curr_filt & country_filt
combined_filt
# Out:
# ResponseId
# 1        False
# 2         True
# 3        False
# 4        False
# 5        False
#          ...
# 89180    False
# 89181    False
# 89182    False
# 89183    False
# 89184    False
# Length: 89184, dtype: bool

# %%
selected_columns = df.loc[combined_filt, ['LanguageHaveWorkedWith', 'Currency', 'Country', 'RemoteWork', 'CompTotal']]
selected_columns
# Out:
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 2                                  HTML/CSS;JavaScript;Python
# 8           Go;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript
# 11                          C#;C++;HTML/CSS;JavaScript;Python
# 14                                          C;C++;Python;Rust
# 22          Bash/Shell (all shells);Delphi;HTML/CSS;PHP;Po...
# ...                                                       ...
# 89114       Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 89126                       C#;HTML/CSS;JavaScript;Python;SQL
# 89140           Bash/Shell (all shells);C++;JavaScript;Python
# 89141                                   JavaScript;Python;SQL
# 89146                                                  Python
#
#                              Currency                   Country  \
# ResponseId
# 2           USD\tUnited States dollar  United States of America
# 8           USD\tUnited States dollar  United States of America
# ...

# %%
#create filtered csv file
selected_columns.to_csv('filtered_data.csv', index=False)

# %%
# Create a boolean filter 'geo_filt' that checks if the 'Country' column in the DataFrame 'df' contains the string 'Georgia'.
# The 'na=False' argument ensures that missing values (NaN) are treated as 'False' in the filter.
geo_filt = df['Country'].str.contains('Georgia', na=False)
geo_filt
# Out:
# ResponseId
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 89180    False
# 89181    False
# 89182    False
# 89183    False
# 89184    False
# Name: Country, Length: 89184, dtype: bool

# %%
df.loc[geo_filt, 'Country'].head(20)
# Out:
# ResponseId
# 422      Georgia
# 503      Georgia
# 740      Georgia
# 819      Georgia
# 1674     Georgia
# 2674     Georgia
# 4138     Georgia
# 4637     Georgia
# 5644     Georgia
# 6173     Georgia
# 10594    Georgia
# 10683    Georgia
# 10701    Georgia
# 11026    Georgia
# 11318    Georgia
# 11346    Georgia
# 11521    Georgia
# 12070    Georgia
# 12266    Georgia
# 12461    Georgia
# Name: Country, dtype: object

# %%
df['Country'].value_counts()['Georgia']
# Out:
# 166

# %%
# Group the DataFrame 'df' by the values in the 'Country' column.
country_grp = df.groupby(['Country']) 
country_grp

# %%
# Calculate the median and mean of the 'CompTotal' column within each group in the 'country_grp' DataFrameGroupBy.
country_grp['CompTotal'].agg(['median', 'mean']).loc['Georgia']
# Out:
# median     65000.000000
# mean      183132.217822
# Name: Georgia, dtype: float64

# %%
df[['Country', 'LanguageHaveWorkedWith']].value_counts()
# Out:
# Country                   LanguageHaveWorkedWith
# United States of America  HTML/CSS;JavaScript;TypeScript              208
#                           Python                                      196
# India                     HTML/CSS;JavaScript;TypeScript              172
# United States of America  C#;HTML/CSS;JavaScript;SQL;TypeScript       143
#                           C#;HTML/CSS;JavaScript;SQL                  123
#                                                                      ...
# Hungary                   Java;JavaScript;Kotlin;Objective-C;Swift      1
#                           Java;JavaScript;Kotlin;TypeScript             1
#                           Java;JavaScript;PHP                           1
#                           Java;JavaScript;SQL;TypeScript                1
# Zimbabwe                  Rust                                          1
# Name: count, Length: 58810, dtype: int64

# %%
total_sum = df.loc[lan_filt, 'LanguageHaveWorkedWith'].count().sum()
total_sum
# Out:
# 21636

# %%
country_grp['LanguageHaveWorkedWith'].value_counts().loc['Georgia']
# Out:
# LanguageHaveWorkedWith
# Python                                                        5
# HTML/CSS;JavaScript;Python;TypeScript                         3
# HTML/CSS;JavaScript;TypeScript                                3
# C#;HTML/CSS;JavaScript;SQL;TypeScript                         2
# C++                                                           2
#                                                              ..
# C#;HTML/CSS;Java;JavaScript;PHP;Python;Rust;SQL;TypeScript    1
# C#;HTML/CSS;TypeScript                                        1
# C#;Java;Python                                                1
# C#;JavaScript;PHP;SQL;TypeScript                              1
# C#;JavaScript;PowerShell;SQL;TypeScript                       1
# Name: count, Length: 145, dtype: int64

# %%
df.loc[lan_filt, ['LanguageHaveWorkedWith', 'Country']]
# Out:
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 2                                  HTML/CSS;JavaScript;Python
# 8           Go;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript
# 10             HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 11                          C#;C++;HTML/CSS;JavaScript;Python
# 12          C#;HTML/CSS;JavaScript;Kotlin;PowerShell;Pytho...
# ...                                                       ...
# 89173       Bash/Shell (all shells);HTML/CSS;JavaScript;Pe...
# 89177       HTML/CSS;Java;JavaScript;PHP;Python;SQL;TypeSc...
# 89181                                    Dart;Java;Python;SQL
# 89182       Assembly;Bash/Shell (all shells);C;C#;Python;R...
# 89183       Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
#
#                              Country
# ResponseId
# 2           United States of America
# 8           United States of America
# 10                             India
# 11          United States of America
# ...

# %%
total = df.loc[lan_filt][['LanguageHaveWorkedWith', 'Country']].value_counts()
total.head()
# Out:
# LanguageHaveWorkedWith          Country
# Python                          United States of America    196
#                                 India                       105
# Python;SQL                      United States of America     98
# Python                          Germany                      90
# Bash/Shell (all shells);Python  United States of America     86
# Name: count, dtype: int64

# %%
total_percentage = (total/total_sum)*100
total_percentage.head()
# Out:
# LanguageHaveWorkedWith          Country
# Python                          United States of America    0.454145
#                                 India                       0.243292
# Python;SQL                      United States of America    0.227073
# Python                          Germany                     0.208536
# Bash/Shell (all shells);Python  United States of America    0.199268
# Name: count, dtype: float64

# %%
sel_columns = df.loc[country_filt, ['Country', 'ConvertedCompYearly']]
sel_columns
# Out:
#                              Country  ConvertedCompYearly
# ResponseId
# 2           United States of America             285000.0
# 3           United States of America             250000.0
# 4           United States of America             156000.0
# 7           United States of America             135000.0
# 8           United States of America              80000.0
# ...                              ...                  ...
# 89165                          India                  NaN
# 89166                          India                  NaN
# 89168                          India              15752.0
# 89176       United States of America                  NaN
# 89179       United States of America                  NaN
#
# [35273 rows x 2 columns]

# %%
df.dropna(subset=['ConvertedCompYearly'], inplace=True)

# %%
df.isnull().sum()
# Out:
# Q120                       0
# MainBranch                 0
# Age                        0
# Employment                12
# RemoteWork                79
#                        ...
# ProfessionalTech       16293
# Industry               20272
# SurveyLength             509
# SurveyEase               471
# ConvertedCompYearly        0
# Length: 83, dtype: int64

# %%
df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
# 6           I agree  I am a developer by profession  35-44 years old
#
#                                                    Employment  \
# ResponseId
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
# 6                                         Employed, full-time
#
#                                       RemoteWork  \
# ResponseId
# 2                                         Remote
# ...

# %%
#first 5 largest Employement column name
emp = df['Employment'].value_counts().nlargest(5)
emp
# Out:
# Employment
# Employed, full-time                                                         39301
# Independent contractor, freelancer, or self-employed                         3906
# Employed, full-time;Independent contractor, freelancer, or self-employed     3291
# Employed, part-time                                                           906
# Independent contractor, freelancer, or self-employed;Employed, part-time      240
# Name: count, dtype: int64

# %%
emp_sum = df['Employment'].count().sum()
emp_sum
# Out:
# 48007

# %%
emp_percentage = (emp/emp_sum) * 100
emp_percentage
# Out:
# Employment
# Employed, full-time                                                         81.865145
# Independent contractor, freelancer, or self-employed                         8.136313
# Employed, full-time;Independent contractor, freelancer, or self-employed     6.855250
# Employed, part-time                                                          1.887225
# Independent contractor, freelancer, or self-employed;Employed, part-time     0.499927
# Name: count, dtype: float64

# %%
import matplotlib.pyplot as plt

# Define neon colors for the bars
neon_colors = ['#FF6B6B', '#75E1FF', '#FFD700', '#FF69B4', '#98FB98']


# Create the horizontal bar chart
fig, ax = plt.subplots()

# Plot the horizontal bars with neon colors
bars = emp_percentage.plot(kind='barh', color=neon_colors, ax=ax)

# Set labels and title
ax.set_xlabel('Percentage')
ax.set_ylabel('Employment Status')
ax.set_title('Employment Status Distribution (Percentage)')

# Add percentages on the bars
for i, v in enumerate(emp_percentage):
    ax.text(v + 1, i, f'{v:.2f}%', va='center', color='black', fontweight='bold')

# Invert the y-axis for a top-down view
ax.invert_yaxis()

# Customize grid lines
ax.xaxis.grid(True, linestyle='--', linewidth=0.5, alpha=0.6)
ax.set_axisbelow(True)

# Customize the grid lines and ticks
ax.set_yticks(range(len(emp_percentage)))  # Corrected missing closing parenthesis
ax.set_yticklabels(emp_percentage.index)

# Set a limit on the x-axis for better readability
ax.set_xlim(0, max(emp_percentage) + 10)


# Adjust the figure size
fig.set_size_inches(8, 6)

# Show the chart
plt.show()

# %%
remote_work = df['RemoteWork'].value_counts()
remote_work
# Out:
# RemoteWork
# Remote                                  21138
# Hybrid (some remote, some in-person)    20276
# In-person                                6526
# Name: count, dtype: int64

# %%
remote_work_sum = df['RemoteWork'].count().sum()
remote_work_sum
# Out:
# 47940

# %%
remote_work_sum_percentage = remote_work/remote_work_sum * 100
remote_work_sum_percentage
# Out:
# RemoteWork
# Remote                                  44.092616
# Hybrid (some remote, some in-person)    42.294535
# In-person                               13.612849
# Name: count, dtype: float64

# %%
import matplotlib.pyplot as plt

# Define neon colors for the bars
neon_colors = ['#FF6B6B', '#75E1FF', '#FFD700', '#FF69B4', '#98FB98']


# Create the horizontal bar chart
fig, ax = plt.subplots()

# Plot the horizontal bars with neon colors
bars = remote_work_sum_percentage.plot(kind='barh', color=neon_colors, ax=ax)

# Set labels and title
ax.set_xlabel('Percentage')
ax.set_ylabel('Remote work status')
ax.set_title('Remote work Status Distribution (Percentage)')

# Add percentages on the bars
for i, v in enumerate(remote_work_sum_percentage):
    ax.text(v + 1, i, f'{v:.2f}%', va='center', color='black', fontweight='bold')

# Invert the y-axis for a top-down view
ax.invert_yaxis()

# Customize grid lines
ax.xaxis.grid(True, linestyle='--', linewidth=0.5, alpha=0.6)
ax.set_axisbelow(True)

# Customize the grid lines and ticks
ax.set_yticks(range(len(remote_work_sum_percentage)))  # Corrected missing closing parenthesis
ax.set_yticklabels(remote_work_sum_percentage.index)

# Set a limit on the x-axis for better readability
ax.set_xlim(0, max(remote_work_sum_percentage) + 10)


# Adjust the figure size
fig.set_size_inches(8, 6)

# Show the chart
plt.show()

# %%
code_activities = df['CodingActivities'].value_counts().nlargest(6)
code_activities
# Out:
# CodingActivities
# Hobby                                                                                                           10759
# I don’t code outside of work                                                                                     6373
# Hobby;Professional development or self-paced learning from online courses                                        5947
# Hobby;Contribute to open-source projects                                                                         3768
# Professional development or self-paced learning from online courses                                              2517
# Hobby;Contribute to open-source projects;Professional development or self-paced learning from online courses     2320
# Name: count, dtype: int64

# %%
code_activities_sum = df['CodingActivities'].value_counts().sum()
code_activities_sum
# Out:
# 47918

# %%
code_activites_percentage = code_activities/code_activities_sum * 100
code_activites_percentage
# Out:
# CodingActivities
# Hobby                                                                                                           22.452940
# I don’t code outside of work                                                                                    13.299804
# Hobby;Professional development or self-paced learning from online courses                                       12.410785
# Hobby;Contribute to open-source projects                                                                         7.863433
# Professional development or self-paced learning from online courses                                              5.252723
# Hobby;Contribute to open-source projects;Professional development or self-paced learning from online courses     4.841604
# Name: count, dtype: float64

# %%
import matplotlib.pyplot as plt

# Define neon colors for the bars
neon_colors = ['#FF6B6B', '#75E1FF', '#FFD700', '#FF69B4', '#98FB98']


# Create the horizontal bar chart
fig, ax = plt.subplots()

# Plot the horizontal bars with neon colors
bars = code_activites_percentage.plot(kind='barh', color=neon_colors, ax=ax)

# Set labels and title
ax.set_xlabel('Percentage')
ax.set_ylabel('Coding status')
ax.set_title('Coding Status Distribution (Percentage)')

# Add percentages on the bars
for i, v in enumerate(code_activites_percentage):
    ax.text(v + 1, i, f'{v:.2f}%', va='center', color='black', fontweight='bold')

# Invert the y-axis for a top-down view
ax.invert_yaxis()

# Customize grid lines
ax.xaxis.grid(True, linestyle='--', linewidth=0.5, alpha=0.6)
ax.set_axisbelow(True)

# Customize the grid lines and ticks
ax.set_yticks(range(len(code_activites_percentage)))  # Corrected missing closing parenthesis
ax.set_yticklabels(code_activites_percentage.index)

# Set a limit on the x-axis for better readability
ax.set_xlim(0, max(code_activites_percentage) + 10)


# Adjust the figure size
fig.set_size_inches(8, 6)

# Show the chart
plt.show()
